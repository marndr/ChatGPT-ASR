# %%
# installations
import sys

# !{sys.executable} -m pip install -U pip setuptools wheel
# !{sys.executable} -m pip install -U spacy
# !{sys.executable} -m pip -m spacy download en_core_web_sm
# !{sys.executable} -m pip install jiwer pandas -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/mnaderi/.local/lib/python3.10/site-packages (24.0)
# Requirement already satisfied: setuptools in /home/mnaderi/.local/lib/python3.10/site-packages (69.1.1)
# Requirement already satisfied: wheel in /home/mnaderi/.local/lib/python3.10/site-packages (0.42.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in /home/mnaderi/.local/lib/python3.10/site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (2.6.1)
# Requirement already satisfied: jinja2 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from spacy) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/mnaderi/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/mnaderi/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mnaderi/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/mnaderi/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/mnaderi/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/mnaderi/.local/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/mnaderi/.local/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy) (2.0.1)
#
# Usage:
#   /usr/bin/python3 -m pip <command> [options]
#
# no such option: -m
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jiwer in /home/mnaderi/.local/lib/python3.10/site-packages (3.0.3)
# Requirement already satisfied: pandas in /home/mnaderi/.local/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/mnaderi/.local/lib/python3.10/site-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in /home/mnaderi/.local/lib/python3.10/site-packages (from jiwer) (3.6.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/mnaderi/.local/lib/python3.10/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mnaderi/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/mnaderi/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import spacy
from jiwer import compute_measures #, RemovePunctuation
import pandas as pd
import json
import re

SPACY_MODEL = "en_core_web_sm"
nlp = spacy.load(SPACY_MODEL)

# %%
def read_data(path):
    # dummy data
    #  data = [
    #     ("The cat sat on the mat.", "The cat sat, on the mat.", "The cat is sitting on the mat."),
    #     ("He walks to the store.", "He walk to the store.", "He walked to the store."),
    #     ("She plays piano very well.", "She play piano very well.", "She plays the piano very well."),
    #     ("I don't go to school", "I don't go to school and", "I go to school.")
    # ]
    with open(path, "r") as f:
        data = json.load(f)
    
    transcriptions = [d["asr_transcription"]["text"] for d in data]
    corrected_transcriptions = [d["corrected_asr_transcription"] for d in data]
    reference_transcriptions = [d["reference_transcription"] for d in data]
    
    assert all([type(r) == str for r in transcriptions]) == True, "transcriptions should be a list of str!"
    assert all([type(r) == str for r in corrected_transcriptions]) == True, "transcriptions should be a list of str!"
    assert all([type(r) == str for r in reference_transcriptions]) == True, "transcriptions should be a list of str!"
    
    return transcriptions, corrected_transcriptions, reference_transcriptions

# %%
def wrapper(remove_punct=True, return_texts=False, return_pos=False):
    def tokenizer_fn(texts):
        tokens = []
        texts_new = []
        poses = []
        for text in texts:
            if remove_punct:
                # remove punctuation
                text = re.sub("[\s]+", " ", text).strip().lower()
                tokens.append([token.text for token in nlp(text) if token.pos_ != "PUNCT"])
                poses.append([token.pos_ for token in nlp(text) if token.pos_ != "PUNCT"])
                text = "".join([token.text_with_ws if token.pos_ != "PUNCT" else " "  for token in nlp(text) ])
                text = re.sub("[\s]+", " ", text).strip().lower()
                # text = RemovePunctuation()(text.lower().strip())
                texts_new.append(text)
            else:
                text = re.sub("[\s]+", " ", text).strip().lower()
                tokens.append([token.text for token in nlp(text)])
                poses.append([token.pos_ for token in nlp(text)])
                text = "".join([token.text_with_ws for token in nlp(text) ])
                text = re.sub("[\s]+", " ", text).strip().lower()
                texts_new.append(text)

        if (return_texts == False) and (return_pos == False):
            return tokens
            
        out = [tokens, None, None]
        if return_texts:
            out[1] = texts_new
        if return_pos:
            out[2] = poses
        return out
        
    return tokenizer_fn

# %%
def extract_words(measures):

    truths_pos, hypotheses_pos, ops, truths, hypotheses = measures['truth_pos'], measures['hypothesis_pos'], measures['ops'], \
                                            measures['truth'], measures['hypothesis']
    n_samples = len(truths)
    words = [[] for i in range(n_samples)]
    pos = [[] for i in range(n_samples)]
    operations = [[] for i in range(n_samples)]
    
    for idx in range(n_samples):
        truth_pos = truths_pos[idx]
        truth = truths[idx]

        hypothesis = hypotheses[idx]
        hypothesis_pos = hypotheses_pos[idx]

        for op in ops[idx]:
            if op.type == "delete":
                words[idx].extend(truth[op.ref_start_idx:op.ref_end_idx])
                pos[idx].extend(truth_pos[op.ref_start_idx:op.ref_end_idx])
                operations[idx].extend(["delete" for _ in truth_pos[op.ref_start_idx:op.ref_end_idx]])
                
            elif op.type == "insert":
                words[idx].extend(hypothesis[op.hyp_start_idx:op.hyp_end_idx])
                pos[idx].extend(hypothesis_pos[op.hyp_start_idx:op.hyp_end_idx])
                operations[idx].extend(["insert" for _ in hypothesis_pos[op.hyp_start_idx:op.hyp_end_idx]])
                
            elif op.type == "substitute":
                # words[idx].extend(truth_text[op.ref_start_idx:op.ref_end_idx])
                # pos[idx].extend(truth_pos[op.ref_start_idx:op.ref_end_idx])
                words[idx].extend(hypothesis[op.hyp_start_idx:op.hyp_end_idx])
                pos[idx].extend(hypothesis_pos[op.hyp_start_idx:op.hyp_end_idx])
                operations[idx].extend(["substitute" for _ in hypothesis_pos[op.hyp_start_idx:op.hyp_end_idx]])
                
            elif op.type == "equal":
                # words[idx].extend(truth_text[op.ref_start_idx:op.ref_end_idx])
                # pos[idx].extend(truth_pos[op.ref_start_idx:op.ref_end_idx])
                words[idx].extend(hypothesis[op.hyp_start_idx:op.hyp_end_idx])
                pos[idx].extend(hypothesis_pos[op.hyp_start_idx:op.hyp_end_idx])
                operations[idx].extend(["equal" for _ in hypothesis_pos[op.hyp_start_idx:op.hyp_end_idx]])

    return words, pos, operations

# %%
def create_table(pos, ops):
    # Flatten the nested lists of pos and ops
    flat_pos = [pos_row for sublist in pos for pos_row in sublist]
    flat_ops = [ops_row for sublist in operations for ops_row in sublist]

    # Get unique parts of speech
    unique_pos = sorted(set(flat_pos))
    unique_ops = set(flat_ops)
    # Create a dictionary to store the cumulative sums for each operation and part of speech
    data = {op: {p: sum(1 for i, j in zip(flat_pos, flat_ops) if i == p and j == op) for p in unique_pos} for op in unique_ops}

    # Convert the dictionary into a DataFrame
    df = pd.DataFrame(data)

    return df.T

# %%
def create_table_wide(pos, operations):
    # Flatten the nested lists of pos and ops
    flat_pos = [pos_row for sublist in pos for pos_row in sublist]
    flat_ops = [ops_row for sublist in operations for ops_row in sublist]

    # Get unique parts of speech
    unique_pos = sorted(set(flat_pos))
    unique_ops = set(flat_ops)
    unique_ops.difference_update({'equal'})

    # Create an empty DataFrame
    df = pd.DataFrame(index=range(len(pos)), columns=[(op, pos_) for op in unique_ops for pos_ in unique_pos])
    
    # Iterate over the examples, counting occurrences of each unique combination
    for i, (p, o) in enumerate(zip(pos, operations)):
        for pos_, op in zip(p, o):
            if (op, pos_) in df.columns:
                df.at[i, (op, pos_)] = df.at[i, (op, pos_)] + 1 if not pd.isna(df.at[i, (op, pos_)]) else 1
    
    # Fill missing values with zeros
    df.fillna(0, inplace=True)
    return df

# %%
# __main__

# path to data
path = "../Documents/thesis/chat-gpt-asr/results/results-dev-set/results_clean/results_tiny/results_best_prompt_tiny/results_GPT-3.5-Turbo_tiny/gpt-3.5-turbo-1106/results_sentence_confidence_new_prompts_tiny/results_find_best_prompt_tiny/corrected_transcriptions_sentence_confidence_prompt_2.json"
# output = "output1.md"

# read data
transcriptions, corrected_transcriptions, reference_transcriptions = read_data(path)

# compute measures
meas = compute_measures(transcriptions, corrected_transcriptions, 
                truth_transform=wrapper(), hypothesis_transform=wrapper())
trans_tokens, trans_texts, trans_poses = wrapper(return_texts=True,return_pos=True)(transcriptions)
c_trans_tokens, c_trans_texts, c_trans_poses = wrapper(return_texts=True,return_pos=True)(corrected_transcriptions)
meas['truth_pos'] = trans_poses 
meas['hypothesis_pos'] = c_trans_poses 

# extract changed words and poses
words, pos, operations = extract_words(meas)

# create table
df = create_table(pos, operations)

# convert to percentage
df = (df.div(df.sum(axis=1), axis=0)*100).round(2)

# remove unimportant columns (poses)
condition = df.sum(axis=0) < 2
columns_to_delete = [k for k,v in dict(condition).items() if v]
df_short = df.drop(columns=columns_to_delete)
# df.to_markdown(output)
df
# Out:
#              ADJ    ADP   ADV   AUX  CCONJ    DET  INTJ   NOUN    NUM  PART  \
# equal       7.42  12.12  5.53  6.55   4.68  10.74  0.20  19.01   0.85  2.68
# substitute  8.77   6.31  4.70  1.61   2.52   2.81  0.14  37.52   0.14  2.10
# delete      2.79   7.32  2.61  6.62   2.26   5.57  0.17  16.90  38.68  2.79
# insert      7.02  11.11  1.75  5.26   5.85  18.13  0.00  23.39   0.58  4.68
#
#              PRON  PROPN  SCONJ   SYM   VERB     X
# equal       12.65   2.21   2.66  0.01  12.67  0.03
# substitute   5.12   7.29   1.61  0.00  19.35  0.00
# delete       3.31   1.74   0.70  0.00   8.54  0.00
# insert       3.51   8.77   1.75  0.58   7.60  0.00

# %%
k = df.shape[1] - 1
selected_ops = ['delete','substitute','insert']
sorted_sum_of_selected_ops = df.loc[selected_ops].sum().sort_values(ascending=False)
df[sorted_sum_of_selected_ops.index[:k]]
# Out:
#              NOUN    NUM   VERB    DET    ADP   ADJ  PROPN   AUX   PRON  \
# equal       19.01   0.85  12.67  10.74  12.12  7.42   2.21  6.55  12.65
# substitute  37.52   0.14  19.35   2.81   6.31  8.77   7.29  1.61   5.12
# delete      16.90  38.68   8.54   5.57   7.32  2.79   1.74  6.62   3.31
# insert      23.39   0.58   7.60  18.13  11.11  7.02   8.77  5.26   3.51
#
#             CCONJ  PART   ADV  SCONJ   SYM  INTJ
# equal        4.68  2.68  5.53   2.66  0.01  0.20
# substitute   2.52  2.10  4.70   1.61  0.00  0.14
# delete       2.26  2.79  2.61   0.70  0.00  0.17
# insert       5.85  4.68  1.75   1.75  0.58  0.00

# %% [markdown]
# # improved/not-improved/same

# %%
df_wide_2 = create_table_wide(pos, operations)
wer_l = []
for idx in df_wide_2.index:
    wer1 = compute_measures(reference_transcriptions[idx], corrected_transcriptions[idx], 
                         truth_transform=wrapper(), hypothesis_transform=wrapper())['wer']
    wer2 = compute_measures(reference_transcriptions[idx], transcriptions[idx], 
                         truth_transform=wrapper(), hypothesis_transform=wrapper())['wer']
    
    if wer1 < wer2: # Chatgpt correction got better
        w = 0
    elif wer1 > wer2: # Chatgpt correction got worse
        w = 1
    else: # Chatgpt correction didn't change
        w = 2
    wer_l.append([wer1, wer2, w])

# df_wide_percent = (df_wide.div(df_wide.sum(axis=1), axis=0)*100).round(2)
df_wide_2['wer_reference_and_corrected_transcription'] = [_[0] for _ in wer_l]
df_wide_2['wer_reference_and_transcription'] = [_[1] for _ in wer_l]
df_wide_2['improved'] = [_[2] for _ in wer_l]

df_wide_2.T
# Out:
# /tmp/ipykernel_70535/108041988.py:21: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0, inplace=True)
#                                            0     1         2     3     4     \
# (substitute, ADJ)                           0.0   0.0  0.000000   0.0   0.0
# (substitute, ADP)                           0.0   0.0  0.000000   0.0   0.0
# (substitute, ADV)                           0.0   0.0  0.000000   0.0   0.0
# (substitute, AUX)                           0.0   0.0  0.000000   0.0   0.0
# (substitute, CCONJ)                         0.0   0.0  0.000000   0.0   0.0
# (substitute, DET)                           0.0   0.0  0.000000   0.0   0.0
# (substitute, INTJ)                          0.0   0.0  0.000000   0.0   0.0
# (substitute, NOUN)                          0.0   0.0  1.000000   0.0   0.0
# (substitute, NUM)                           0.0   0.0  0.000000   0.0   0.0
# (substitute, PART)                          0.0   0.0  0.000000   0.0   0.0
# (substitute, PRON)                          0.0   0.0  0.000000   0.0   0.0
# (substitute, PROPN)                         0.0   0.0  0.000000   0.0   0.0
# (substitute, SCONJ)                         0.0   0.0  0.000000   0.0   0.0
# (substitute, SYM)                           0.0   0.0  0.000000   0.0   0.0
# (substitute, VERB)                          0.0   0.0  0.000000   0.0   0.0
# (substitute, X)                             0.0   0.0  0.000000   0.0   0.0
# (delete, ADJ)                               0.0   0.0  0.000000   0.0   0.0
# (delete, ADP)                               0.0   0.0  0.000000   0.0   0.0
# (delete, ADV)                               0.0   0.0  0.000000   0.0   0.0
# (delete, AUX)                               0.0   0.0  0.000000   0.0   0.0
# (delete, CCONJ)                             0.0   0.0  0.000000   0.0   0.0
# (delete, DET)                               0.0   0.0  0.000000   0.0   0.0
# (delete, INTJ)                              0.0   0.0  0.000000   0.0   0.0
# (delete, NOUN)                              0.0   0.0  0.000000   0.0   0.0
# (delete, NUM)                               0.0   0.0  0.000000   0.0   0.0
# (delete, PART)                              0.0   0.0  0.000000   0.0   0.0
# (delete, PRON)                              0.0   0.0  0.000000   0.0   0.0
# (delete, PROPN)                             0.0   0.0  0.000000   0.0   0.0
# (delete, SCONJ)                             0.0   0.0  0.000000   0.0   0.0
# (delete, SYM)                               0.0   0.0  0.000000   0.0   0.0
# (delete, VERB)                              0.0   0.0  0.000000   0.0   0.0
# (delete, X)                                 0.0   0.0  0.000000   0.0   0.0
# (insert, ADJ)                               0.0   0.0  0.000000   0.0   0.0
# (insert, ADP)                               0.0   0.0  0.000000   0.0   0.0
# (insert, ADV)                               0.0   0.0  0.000000   0.0   0.0
# (insert, AUX)                               0.0   0.0  0.000000   0.0   0.0
# (insert, CCONJ)                             0.0   0.0  0.000000   0.0   0.0
# (insert, DET)                               0.0   0.0  0.000000   0.0   0.0
# (insert, INTJ)                              0.0   0.0  0.000000   0.0   0.0
# (insert, NOUN)                              0.0   0.0  0.000000   0.0   0.0
# (insert, NUM)                               0.0   0.0  0.000000   0.0   0.0
# (insert, PART)                              0.0   0.0  0.000000   0.0   0.0
# (insert, PRON)                              0.0   0.0  0.000000   0.0   0.0
# (insert, PROPN)                             0.0   0.0  0.000000   0.0   0.0
# (insert, SCONJ)                             0.0   0.0  0.000000   0.0   0.0
# (insert, SYM)                               0.0   0.0  0.000000   0.0   0.0
# (insert, VERB)                              0.0   0.0  0.000000   0.0   0.0
# (insert, X)                                 0.0   0.0  0.000000   0.0   0.0
# wer_reference_and_corrected_transcription   0.0   0.0  0.083333   0.0   0.0
# wer_reference_and_transcription             0.0   0.0  0.083333   0.0   0.0
# improved                                    2.0   2.0  2.000000   2.0   2.0
#
#                                                5     6         7         8     \
# (substitute, ADJ)                          0.000000   0.0  0.000000  1.000000
# (substitute, ADP)                          0.000000   0.0  0.000000  0.000000
# (substitute, ADV)                          0.000000   0.0  0.000000  0.000000
# (substitute, AUX)                          0.000000   0.0  0.000000  0.000000
# (substitute, CCONJ)                        0.000000   0.0  0.000000  0.000000
# (substitute, DET)                          0.000000   0.0  1.000000  0.000000
# (substitute, INTJ)                         0.000000   0.0  0.000000  0.000000
# (substitute, NOUN)                         2.000000   0.0  1.000000  0.000000
# (substitute, NUM)                          0.000000   0.0  0.000000  0.000000
# (substitute, PART)                         0.000000   0.0  0.000000  0.000000
# (substitute, PRON)                         0.000000   0.0  0.000000  0.000000
# (substitute, PROPN)                        0.000000   0.0  0.000000  0.000000
# (substitute, SCONJ)                        0.000000   0.0  0.000000  0.000000
# (substitute, SYM)                          0.000000   0.0  0.000000  0.000000
# (substitute, VERB)                         0.000000   0.0  0.000000  0.000000
# (substitute, X)                            0.000000   0.0  0.000000  0.000000
# (delete, ADJ)                              0.000000   0.0  0.000000  0.000000
# (delete, ADP)                              0.000000   0.0  0.000000  0.000000
# (delete, ADV)                              0.000000   0.0  0.000000  0.000000
# (delete, AUX)                              0.000000   0.0  1.000000  0.000000
# (delete, CCONJ)                            0.000000   0.0  0.000000  0.000000
# (delete, DET)                              0.000000   0.0  0.000000  0.000000
# (delete, INTJ)                             0.000000   0.0  0.000000  0.000000
# (delete, NOUN)                             1.000000   0.0  0.000000  0.000000
# (delete, NUM)                              0.000000   0.0  0.000000  0.000000
# (delete, PART)                             0.000000   0.0  0.000000  0.000000
# (delete, PRON)                             0.000000   0.0  0.000000  0.000000
# (delete, PROPN)                            0.000000   0.0  0.000000  0.000000
# (delete, SCONJ)                            0.000000   0.0  0.000000  0.000000
# (delete, SYM)                              0.000000   0.0  0.000000  0.000000
# (delete, VERB)                             0.000000   0.0  0.000000  0.000000
# (delete, X)                                0.000000   0.0  0.000000  0.000000
# (insert, ADJ)                              0.000000   0.0  0.000000  0.000000
# (insert, ADP)                              0.000000   0.0  0.000000  0.000000
# (insert, ADV)                              0.000000   0.0  0.000000  0.000000
# (insert, AUX)                              0.000000   0.0  0.000000  0.000000
# (insert, CCONJ)                            0.000000   0.0  0.000000  0.000000
# (insert, DET)                              0.000000   0.0  0.000000  0.000000
# (insert, INTJ)                             0.000000   0.0  0.000000  0.000000
# (insert, NOUN)                             0.000000   0.0  0.000000  0.000000
# (insert, NUM)                              0.000000   0.0  0.000000  0.000000
# (insert, PART)                             0.000000   0.0  0.000000  0.000000
# (insert, PRON)                             0.000000   0.0  0.000000  0.000000
# (insert, PROPN)                            0.000000   0.0  0.000000  0.000000
# (insert, SCONJ)                            0.000000   0.0  0.000000  0.000000
# (insert, SYM)                              0.000000   0.0  0.000000  0.000000
# (insert, VERB)                             0.000000   0.0  0.000000  0.000000
# (insert, X)                                0.000000   0.0  0.000000  0.000000
# wer_reference_and_corrected_transcription  0.066667   0.0  0.090909  0.000000
# wer_reference_and_transcription            0.033333   0.0  0.159091  0.034483
# improved                                   1.000000   2.0  0.000000  0.000000
#
#                                            9     ...      2693      2694  \
# (substitute, ADJ)                           0.0  ...  0.000000  0.000000
# (substitute, ADP)                           0.0  ...  0.000000  0.000000
# (substitute, ADV)                           0.0  ...  0.000000  0.000000
# (substitute, AUX)                           0.0  ...  0.000000  0.000000
# (substitute, CCONJ)                         0.0  ...  0.000000  0.000000
# (substitute, DET)                           0.0  ...  0.000000  0.000000
# (substitute, INTJ)                          0.0  ...  0.000000  0.000000
# (substitute, NOUN)                          0.0  ...  0.000000  1.000000
# (substitute, NUM)                           0.0  ...  0.000000  0.000000
# (substitute, PART)                          0.0  ...  0.000000  0.000000
# (substitute, PRON)                          0.0  ...  0.000000  0.000000
# (substitute, PROPN)                         0.0  ...  0.000000  0.000000
# (substitute, SCONJ)                         0.0  ...  0.000000  0.000000
# (substitute, SYM)                           0.0  ...  0.000000  0.000000
# (substitute, VERB)                          0.0  ...  0.000000  0.000000
# (substitute, X)                             0.0  ...  0.000000  0.000000
# (delete, ADJ)                               0.0  ...  0.000000  0.000000
# (delete, ADP)                               0.0  ...  0.000000  0.000000
# (delete, ADV)                               0.0  ...  0.000000  0.000000
# (delete, AUX)                               0.0  ...  0.000000  0.000000
# (delete, CCONJ)                             0.0  ...  0.000000  0.000000
# (delete, DET)                               0.0  ...  0.000000  0.000000
# (delete, INTJ)                              0.0  ...  0.000000  0.000000
# (delete, NOUN)                              0.0  ...  0.000000  0.000000
# (delete, NUM)                               0.0  ...  0.000000  0.000000
# (delete, PART)                              0.0  ...  0.000000  0.000000
# (delete, PRON)                              0.0  ...  0.000000  0.000000
# (delete, PROPN)                             0.0  ...  0.000000  0.000000
# (delete, SCONJ)                             0.0  ...  0.000000  0.000000
# (delete, SYM)                               0.0  ...  0.000000  0.000000
# (delete, VERB)                              0.0  ...  0.000000  0.000000
# (delete, X)                                 0.0  ...  0.000000  0.000000
# (insert, ADJ)                               0.0  ...  0.000000  0.000000
# (insert, ADP)                               0.0  ...  0.000000  0.000000
# (insert, ADV)                               0.0  ...  0.000000  0.000000
# (insert, AUX)                               0.0  ...  0.000000  0.000000
# (insert, CCONJ)                             0.0  ...  0.000000  0.000000
# (insert, DET)                               0.0  ...  0.000000  0.000000
# (insert, INTJ)                              0.0  ...  0.000000  0.000000
# (insert, NOUN)                              0.0  ...  0.000000  0.000000
# (insert, NUM)                               0.0  ...  0.000000  0.000000
# (insert, PART)                              0.0  ...  0.000000  0.000000
# (insert, PRON)                              0.0  ...  0.000000  0.000000
# (insert, PROPN)                             0.0  ...  0.000000  0.000000
# (insert, SCONJ)                             0.0  ...  0.000000  0.000000
# (insert, SYM)                               0.0  ...  0.000000  0.000000
# (insert, VERB)                              0.0  ...  0.000000  0.000000
# (insert, X)                                 0.0  ...  0.000000  0.000000
# wer_reference_and_corrected_transcription   0.0  ...  0.142857  0.000000
# wer_reference_and_transcription             0.0  ...  0.142857  0.041667
# improved                                    2.0  ...  2.000000  0.000000
#
#                                            2695      2696  2697      2698  \
# (substitute, ADJ)                           0.0  0.000000   0.0  0.000000
# (substitute, ADP)                           0.0  0.000000   0.0  0.000000
# (substitute, ADV)                           0.0  0.000000   0.0  0.000000
# (substitute, AUX)                           0.0  0.000000   0.0  0.000000
# (substitute, CCONJ)                         0.0  0.000000   0.0  0.000000
# (substitute, DET)                           0.0  0.000000   0.0  0.000000
# (substitute, INTJ)                          0.0  0.000000   0.0  0.000000
# (substitute, NOUN)                          0.0  0.000000   0.0  1.000000
# (substitute, NUM)                           0.0  0.000000   0.0  0.000000
# (substitute, PART)                          0.0  0.000000   0.0  0.000000
# (substitute, PRON)                          0.0  1.000000   0.0  0.000000
# (substitute, PROPN)                         0.0  0.000000   0.0  0.000000
# (substitute, SCONJ)                         0.0  0.000000   0.0  0.000000
# (substitute, SYM)                           0.0  0.000000   0.0  0.000000
# (substitute, VERB)                          0.0  0.000000   0.0  0.000000
# (substitute, X)                             0.0  0.000000   0.0  0.000000
# (delete, ADJ)                               0.0  0.000000   0.0  0.000000
# (delete, ADP)                               0.0  0.000000   0.0  0.000000
# (delete, ADV)                               0.0  0.000000   0.0  0.000000
# (delete, AUX)                               0.0  1.000000   0.0  0.000000
# (delete, CCONJ)                             0.0  0.000000   0.0  0.000000
# (delete, DET)                               0.0  0.000000   0.0  0.000000
# (delete, INTJ)                              0.0  0.000000   0.0  0.000000
# (delete, NOUN)                              0.0  0.000000   0.0  0.000000
# (delete, NUM)                               0.0  0.000000   0.0  0.000000
# (delete, PART)                              0.0  0.000000   0.0  0.000000
# (delete, PRON)                              0.0  0.000000   0.0  0.000000
# (delete, PROPN)                             0.0  0.000000   0.0  0.000000
# (delete, SCONJ)                             0.0  0.000000   0.0  0.000000
# (delete, SYM)                               0.0  0.000000   0.0  0.000000
# (delete, VERB)                              0.0  0.000000   0.0  0.000000
# (delete, X)                                 0.0  0.000000   0.0  0.000000
# (insert, ADJ)                               0.0  0.000000   0.0  0.000000
# (insert, ADP)                               0.0  0.000000   0.0  0.000000
# (insert, ADV)                               0.0  0.000000   0.0  0.000000
# (insert, AUX)                               0.0  0.000000   0.0  0.000000
# (insert, CCONJ)                             0.0  0.000000   0.0  0.000000
# (insert, DET)                               0.0  0.000000   0.0  0.000000
# (insert, INTJ)                              0.0  0.000000   0.0  0.000000
# (insert, NOUN)                              0.0  0.000000   0.0  0.000000
# (insert, NUM)                               0.0  0.000000   0.0  0.000000
# (insert, PART)                              0.0  0.000000   0.0  0.000000
# (insert, PRON)                              0.0  0.000000   0.0  0.000000
# (insert, PROPN)                             0.0  0.000000   0.0  0.000000
# (insert, SCONJ)                             0.0  0.000000   0.0  0.000000
# (insert, SYM)                               0.0  0.000000   0.0  0.000000
# (insert, VERB)                              0.0  0.000000   0.0  0.000000
# (insert, X)                                 0.0  0.000000   0.0  0.000000
# wer_reference_and_corrected_transcription   0.2  0.000000   0.2  0.054054
# wer_reference_and_transcription             0.2  0.071429   0.2  0.081081
# improved                                    2.0  0.000000   2.0  0.000000
#
#                                            2699  2700  2701      2702
# (substitute, ADJ)                           0.0   0.0   0.0  0.000000
# (substitute, ADP)                           0.0   0.0   0.0  0.000000
# (substitute, ADV)                           0.0   0.0   0.0  0.000000
# (substitute, AUX)                           0.0   0.0   0.0  0.000000
# (substitute, CCONJ)                         0.0   0.0   0.0  0.000000
# (substitute, DET)                           0.0   0.0   0.0  0.000000
# (substitute, INTJ)                          0.0   0.0   0.0  0.000000
# (substitute, NOUN)                          0.0   0.0   0.0  0.000000
# (substitute, NUM)                           0.0   0.0   0.0  0.000000
# (substitute, PART)                          0.0   0.0   0.0  0.000000
# (substitute, PRON)                          0.0   0.0   0.0  0.000000
# (substitute, PROPN)                         0.0   0.0   0.0  0.000000
# (substitute, SCONJ)                         0.0   0.0   0.0  0.000000
# (substitute, SYM)                           0.0   0.0   0.0  0.000000
# (substitute, VERB)                          0.0   0.0   0.0  0.000000
# (substitute, X)                             0.0   0.0   0.0  0.000000
# (delete, ADJ)                               0.0   0.0   0.0  0.000000
# (delete, ADP)                               0.0   0.0   0.0  0.000000
# (delete, ADV)                               0.0   0.0   0.0  0.000000
# (delete, AUX)                               0.0   0.0   0.0  0.000000
# (delete, CCONJ)                             0.0   0.0   0.0  0.000000
# (delete, DET)                               0.0   0.0   0.0  0.000000
# (delete, INTJ)                              0.0   0.0   0.0  0.000000
# (delete, NOUN)                              0.0   0.0   0.0  0.000000
# (delete, NUM)                               0.0   0.0   0.0  0.000000
# (delete, PART)                              0.0   0.0   0.0  0.000000
# (delete, PRON)                              0.0   0.0   0.0  0.000000
# (delete, PROPN)                             0.0   0.0   0.0  0.000000
# (delete, SCONJ)                             0.0   0.0   0.0  0.000000
# (delete, SYM)                               0.0   0.0   0.0  0.000000
# (delete, VERB)                              0.0   0.0   0.0  0.000000
# (delete, X)                                 0.0   0.0   0.0  0.000000
# (insert, ADJ)                               0.0   0.0   0.0  0.000000
# (insert, ADP)                               0.0   0.0   0.0  1.000000
# (insert, ADV)                               0.0   0.0   0.0  0.000000
# (insert, AUX)                               0.0   0.0   0.0  0.000000
# (insert, CCONJ)                             0.0   0.0   0.0  0.000000
# (insert, DET)                               0.0   0.0   0.0  0.000000
# (insert, INTJ)                              0.0   0.0   0.0  0.000000
# (insert, NOUN)                              0.0   0.0   0.0  0.000000
# (insert, NUM)                               0.0   0.0   0.0  0.000000
# (insert, PART)                              0.0   0.0   0.0  0.000000
# (insert, PRON)                              0.0   0.0   0.0  0.000000
# (insert, PROPN)                             0.0   0.0   0.0  0.000000
# (insert, SCONJ)                             0.0   0.0   0.0  0.000000
# (insert, SYM)                               0.0   0.0   0.0  0.000000
# (insert, VERB)                              0.0   0.0   0.0  1.000000
# (insert, X)                                 0.0   0.0   0.0  0.000000
# wer_reference_and_corrected_transcription   0.0   0.0   0.0  0.103448
# wer_reference_and_transcription             0.0   0.0   0.0  0.034483
# improved                                    2.0   2.0   2.0  1.000000
#
# [51 rows x 2703 columns]

# %%
sizes = df_wide_2.groupby('improved').size()
sizes
# Out:
# improved
# 0     713
# 1     131
# 2    1859
# dtype: int64

# %%
total_examples = sizes.sum()
improved_examples = sizes[0]
worse_examples = sizes[1]
not_changed_examples = sizes[2]

round(improved_examples/total_examples*100,2), \
round(worse_examples/total_examples*100,2), \
round(not_changed_examples/total_examples*100,2), \
total_examples
# Out:
# (26.38, 4.85, 68.78, 2703)

# %%
(10.59-18.49)/10.59*100
# Out:
# -74.59867799811141

# %%
df_wide_2.groupby('improved').mean().T
# Out:
# improved                                          0         1         2
# (substitute, ADJ)                          0.124825  0.129771  0.010221
# (substitute, ADP)                          0.096774  0.099237  0.004303
# (substitute, ADV)                          0.071529  0.076336  0.003228
# (substitute, AUX)                          0.025245  0.030534  0.000538
# (substitute, CCONJ)                        0.044881  0.022901  0.000538
# (substitute, DET)                          0.040673  0.038168  0.003228
# (substitute, INTJ)                         0.001403  0.000000  0.000538
# (substitute, NOUN)                         0.542777  0.412214  0.050565
# (substitute, NUM)                          0.001403  0.000000  0.000538
# (substitute, PART)                         0.035063  0.015267  0.001614
# (substitute, PRON)                         0.077139  0.061069  0.005379
# (substitute, PROPN)                        0.110799  0.045802  0.010221
# (substitute, SCONJ)                        0.025245  0.038168  0.000000
# (substitute, SYM)                          0.000000  0.000000  0.000000
# (substitute, VERB)                         0.301543  0.122137  0.024207
# (substitute, X)                            0.000000  0.000000  0.000000
# (delete, ADJ)                              0.019635  0.015267  0.000000
# (delete, ADP)                              0.039271  0.091603  0.001076
# (delete, ADV)                              0.007013  0.053435  0.001614
# (delete, AUX)                              0.049088  0.007634  0.001076
# (delete, CCONJ)                            0.011220  0.030534  0.000538
# (delete, DET)                              0.030856  0.068702  0.000538
# (delete, INTJ)                             0.001403  0.000000  0.000000
# (delete, NOUN)                             0.086957  0.229008  0.002690
# (delete, NUM)                              0.307153  0.022901  0.000000
# (delete, PART)                             0.018233  0.015267  0.000538
# (delete, PRON)                             0.018233  0.015267  0.002152
# (delete, PROPN)                            0.014025  0.000000  0.000000
# (delete, SCONJ)                            0.004208  0.007634  0.000000
# (delete, SYM)                              0.000000  0.000000  0.000000
# (delete, VERB)                             0.044881  0.114504  0.001076
# (delete, X)                                0.000000  0.000000  0.000000
# (insert, ADJ)                              0.009818  0.022901  0.001076
# (insert, ADP)                              0.014025  0.038168  0.002152
# (insert, ADV)                              0.002805  0.007634  0.000000
# (insert, AUX)                              0.007013  0.015267  0.001076
# (insert, CCONJ)                            0.009818  0.022901  0.000000
# (insert, DET)                              0.023843  0.076336  0.002152
# (insert, INTJ)                             0.000000  0.000000  0.000000
# (insert, NOUN)                             0.047686  0.030534  0.001076
# (insert, NUM)                              0.001403  0.000000  0.000000
# (insert, PART)                             0.005610  0.022901  0.000538
# (insert, PRON)                             0.004208  0.022901  0.000000
# (insert, PROPN)                            0.016830  0.015267  0.000538
# (insert, SCONJ)                            0.004208  0.000000  0.000000
# (insert, SYM)                              0.000000  0.007634  0.000000
# (insert, VERB)                             0.008415  0.030534  0.001614
# (insert, X)                                0.000000  0.000000  0.000000
# wer_reference_and_corrected_transcription  0.064405  0.184902  0.081959
# wer_reference_and_transcription            0.152448  0.105866  0.081959

# %%
selected_columns = list(set(df_wide_2.columns).difference({
    'wer_reference_and_corrected_transcription',
    'wer_reference_and_transcription',
    'improved'
}))

tt = df_wide_2.groupby('improved').mean()
# Calculate the sum of each column in the subset
subset_sum = tt[selected_columns].sum()
# Sort the summed values in descending order
sorted_subset_sum = subset_sum.sort_values(ascending=False)
# Define the value of k
k = 5  # Change this to your desired value
# Select the top k columns
top_k_columns = sorted_subset_sum.head(k)
top_k_columns
tt1 = tt[top_k_columns.index.tolist() + ["wer_reference_and_corrected_transcription", "wer_reference_and_transcription"]]
tt1
# Out:
#           (substitute, NOUN)  (substitute, VERB)  (delete, NUM)  \
# improved
# 0                   0.542777            0.301543       0.307153
# 1                   0.412214            0.122137       0.022901
# 2                   0.050565            0.024207       0.000000
#
#           (delete, NOUN)  (substitute, ADJ)  \
# improved
# 0               0.086957           0.124825
# 1               0.229008           0.129771
# 2               0.002690           0.010221
#
#           wer_reference_and_corrected_transcription  \
# improved
# 0                                          0.064405
# 1                                          0.184902
# 2                                          0.081959
#
#           wer_reference_and_transcription
# improved
# 0                                0.152448
# 1                                0.105866
# 2                                0.081959

# %%
import matplotlib.pyplot as plt 

x = [ f"{i}_{j}" for i, j in top_k_columns.index.tolist()]
plt.figure(figsize=(4,4), constrained_layout=True)
plt.plot(x, tt1.loc[0, top_k_columns.index.tolist()].values, "g-o", label=f"Improved")
plt.plot(x, tt1.loc[1, top_k_columns.index.tolist()].values, "r-o", label=f"Worsened")
plt.plot(x, tt1.loc[2, top_k_columns.index.tolist()].values, "b-o", label=f"No Change")
plt.xticks(rotation=45)
plt.ylabel("Avg value")
# plt.title(f'top-{k} ChatGPT changes')
plt.title(f'dev-clean')
plt.legend()
plt.savefig(f'top-{k}-dev-clean-3-classes.png', bbox_inches='tight')
